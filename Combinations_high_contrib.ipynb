# %% [markdown]
# # High Contribution

# %%
import numpy as np
import pandas as pd 
import tensorflow as tf
import tensorflow.keras as ks

#unsupervised:
from sklearn.cluster import KMeans
#transformers:
from sklearn.preprocessing import OneHotEncoder, TargetEncoder, StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin
import scipy.stats as st

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

from itertools import combinations


#Note: train data has 13 feature column and 1 binary label for a total of 14 columns

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head(3)
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
#
#    Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0      0.0              2        1.0             0.0        181449.97       0
# 1      0.0              2        1.0             1.0         49503.50       0
# 2      0.0              2        1.0             0.0        184866.69       0

# %%
train.shape
# Out:
# (165034, 14)

# %%
#Age (log) vs Estimated Salary
def kmeansAnalyzer(column_names, n_clusters_max = 14):
    trex = train[column_names].copy()
    se = StandardScaler()
    trex_ = se.fit_transform(trex)
    
    sse = []
    for i in range(2, n_clusters_max + 1):
        tt = KMeans(n_clusters = i, n_init = 10, random_state = 11)
        tt.fit(trex_)
        nx = tt.predict(trex_)
        nx1 = pd.DataFrame(nx, columns = ['group_id'])
        nx1 = pd.merge(nx1, train.Exited, left_index = True, right_index = True)
        z = pd.crosstab(nx1.group_id, nx1.Exited)
        result = st.chi2_contingency(z)
        sse.append((i, tt.inertia_, result.statistic, result.pvalue))
    
    for_plot = pd.DataFrame(sse, columns = ['n_clusters', 'sse', 'stat', 'pval'])
    #plot now:
    
    plt.plot(for_plot.n_clusters, for_plot.sse)
    plt.xlabel("Number of Clusters")
    plt.ylabel("SSE")
    plt.show()
    
    return for_plot

# %%
# combination of categorical and Numeric data:
class ComboCatNumeric(BaseEstimator, TransformerMixin):
    def __init__(self, cat_columns = [], num_columns = [], n_clusters =6, random_state=11):
        self.cat_columns = cat_columns
        self.num_columns = num_columns
        self.n_clusters = n_clusters
        self.random_state = random_state
        self.standardScaler = StandardScaler()
        self.oneHotEncoder = OneHotEncoder(sparse_output =False)
        self.kmeans = KMeans(n_clusters = n_clusters, n_init = 10, random_state = self.random_state, max_iter = 50)
        self.targetEncoder = TargetEncoder(target_type = 'binary', random_state = self.random_state)
        print("Creating transformer combos for {} and {}.".format(self.cat_columns, self.num_columns))

    def fit(self, X, y):
        a1 = []
        a2 = []
        if(len(self.cat_columns) > 0):
            self.oneHotEncoder.fit(X[self.cat_columns])
            a1 = self.oneHotEncoder.transform(X[self.cat_columns])
        if(len(self.num_columns) > 0):
            a2 = np.array(X[self.num_columns])
            a2 = self.standardScaler.fit_transform(a2)
        if(len(a1) > 0 and len(a2) > 0):
            b1 = np.c_[a1,a2]
        if(len(a1) > 0 and len(a2) < 1):
            b1 = a1
        if(len(a1) < 1 and len(a2) > 0):
            b1 = a2
            
        self.kmeans.fit(b1)
        b2 = self.kmeans.predict(b1)
        self.targetEncoder.fit(b2.reshape(-1,1),y)
        return self

    def transform(self, X):
        a1 = []
        a2 = []
        if(len(self.cat_columns) > 0):
            a1 = self.oneHotEncoder.transform(X[self.cat_columns])
        if(len(self.num_columns) > 0):
            a2 = np.array(X[self.num_columns])
            a2 = self.standardScaler.transform(a2)
        if(len(a1) > 0 and len(a2) > 0):
            b1 = np.c_[a1,a2]
        if(len(a1) > 0 and len(a2) < 1):
            b1 = a1
        if(len(a1) < 1 and len(a2) > 0):
            b1 = a2
            
        b2 = self.kmeans.predict(b1)
        c = self.targetEncoder.transform(b2.reshape(-1,1))
        print("Completed the transformer combos for {} and {}.".format(self.cat_columns, self.num_columns))
        return c.reshape(-1,1)

# %%
# Transform into KMeans
class KMeansTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, cat_columns = [], num_columns = [], n_clusters =6, random_state=11):
        self.cat_columns = cat_columns
        self.num_columns = num_columns
        self.n_clusters = n_clusters
        self.random_state = random_state
        self.standardScaler = StandardScaler()
        self.oneHotEncoder = OneHotEncoder(sparse_output =False)
        self.kmeans = KMeans(n_clusters = n_clusters, n_init = 10, random_state = self.random_state, max_iter = 50)
        self.targetEncoder = TargetEncoder(target_type = 'binary', random_state = self.random_state)
        print("Creating transformer combos for {} and {}.".format(self.cat_columns, self.num_columns))

    def fit(self, X, y = None):
        a1 = []
        a2 = []
        if(len(self.cat_columns) > 0):
            self.oneHotEncoder.fit(X[self.cat_columns])
            a1 = self.oneHotEncoder.transform(X[self.cat_columns])
        if(len(self.num_columns) > 0):
            a2 = np.array(X[self.num_columns])
            a2 = self.standardScaler.fit_transform(a2)
        if(len(a1) > 0 and len(a2) > 0):
            b1 = np.c_[a1,a2]
        if(len(a1) > 0 and len(a2) < 1):
            b1 = a1
        if(len(a1) < 1 and len(a2) > 0):
            b1 = a2
            
        self.kmeans.fit(b1)
        return self

    def transform(self, X):
        a1 = []
        a2 = []
        if(len(self.cat_columns) > 0):
            a1 = self.oneHotEncoder.transform(X[self.cat_columns])
        if(len(self.num_columns) > 0):
            a2 = np.array(X[self.num_columns])
            a2 = self.standardScaler.transform(a2)
        if(len(a1) > 0 and len(a2) > 0):
            b1 = np.c_[a1,a2]
        if(len(a1) > 0 and len(a2) < 1):
            b1 = a1
        if(len(a1) < 1 and len(a2) > 0):
            b1 = a2
            
        b2 = self.kmeans.predict(b1)
        
        return b2.reshape(-1,1)

# %%
#Get combinations
cat_list =['Geography', 'Gender'] 
num_list =['Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'CreditScore']

result_list = []
two = list(combinations(num_list,2))
for i in cat_list:
    for j in two:
        print("checking for {} and {} combos.".format(i, j))
        kk = KMeansTransformer(cat_columns = [i], num_columns = [j[0],j[1]], n_clusters = 4)
        r = kk.fit(train)
        r1 = kk.transform(train)
        zz = pd.DataFrame(np.c_[r1, train.Exited])
        cc = pd.crosstab(zz.iloc[:,0], zz.iloc[:,1])
        result = st.chi2_contingency(cc)
        result_list.append((result.statistic, i, j))
        del r, r1, zz, cc, result
# Out:
# checking for Geography and ('Age', 'Tenure') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Tenure'].
# checking for Geography and ('Age', 'Balance') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Balance'].
# checking for Geography and ('Age', 'NumOfProducts') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'NumOfProducts'].
# checking for Geography and ('Age', 'HasCrCard') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'HasCrCard'].
# checking for Geography and ('Age', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'IsActiveMember'].
# checking for Geography and ('Age', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'EstimatedSalary'].
# checking for Geography and ('Age', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'CreditScore'].
# checking for Geography and ('Tenure', 'Balance') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'Balance'].
# checking for Geography and ('Tenure', 'NumOfProducts') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'NumOfProducts'].
# checking for Geography and ('Tenure', 'HasCrCard') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'HasCrCard'].
# checking for Geography and ('Tenure', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'IsActiveMember'].
# checking for Geography and ('Tenure', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'EstimatedSalary'].
# checking for Geography and ('Tenure', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'CreditScore'].
# checking for Geography and ('Balance', 'NumOfProducts') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'NumOfProducts'].
# checking for Geography and ('Balance', 'HasCrCard') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'HasCrCard'].
# checking for Geography and ('Balance', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'IsActiveMember'].
# checking for Geography and ('Balance', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'EstimatedSalary'].
# checking for Geography and ('Balance', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'CreditScore'].
# checking for Geography and ('NumOfProducts', 'HasCrCard') combos.
# Creating transformer combos for ['Geography'] and ['NumOfProducts', 'HasCrCard'].
# checking for Geography and ('NumOfProducts', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['NumOfProducts', 'IsActiveMember'].
# checking for Geography and ('NumOfProducts', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['NumOfProducts', 'EstimatedSalary'].
# checking for Geography and ('NumOfProducts', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['NumOfProducts', 'CreditScore'].
# checking for Geography and ('HasCrCard', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['HasCrCard', 'IsActiveMember'].
# checking for Geography and ('HasCrCard', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['HasCrCard', 'EstimatedSalary'].
# checking for Geography and ('HasCrCard', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['HasCrCard', 'CreditScore'].
# checking for Geography and ('IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['IsActiveMember', 'EstimatedSalary'].
# checking for Geography and ('IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['IsActiveMember', 'CreditScore'].
# checking for Geography and ('EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['EstimatedSalary', 'CreditScore'].
# checking for Gender and ('Age', 'Tenure') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Tenure'].
# checking for Gender and ('Age', 'Balance') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Balance'].
# checking for Gender and ('Age', 'NumOfProducts') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'NumOfProducts'].
# checking for Gender and ('Age', 'HasCrCard') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'HasCrCard'].
# checking for Gender and ('Age', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'IsActiveMember'].
# checking for Gender and ('Age', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'EstimatedSalary'].
# checking for Gender and ('Age', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'CreditScore'].
# checking for Gender and ('Tenure', 'Balance') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'Balance'].
# checking for Gender and ('Tenure', 'NumOfProducts') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'NumOfProducts'].
# checking for Gender and ('Tenure', 'HasCrCard') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'HasCrCard'].
# checking for Gender and ('Tenure', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'IsActiveMember'].
# checking for Gender and ('Tenure', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'EstimatedSalary'].
# checking for Gender and ('Tenure', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'CreditScore'].
# checking for Gender and ('Balance', 'NumOfProducts') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'NumOfProducts'].
# checking for Gender and ('Balance', 'HasCrCard') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'HasCrCard'].
# checking for Gender and ('Balance', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'IsActiveMember'].
# checking for Gender and ('Balance', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'EstimatedSalary'].
# checking for Gender and ('Balance', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'CreditScore'].
# checking for Gender and ('NumOfProducts', 'HasCrCard') combos.
# Creating transformer combos for ['Gender'] and ['NumOfProducts', 'HasCrCard'].
# checking for Gender and ('NumOfProducts', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['NumOfProducts', 'IsActiveMember'].
# checking for Gender and ('NumOfProducts', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['NumOfProducts', 'EstimatedSalary'].
# checking for Gender and ('NumOfProducts', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['NumOfProducts', 'CreditScore'].
# checking for Gender and ('HasCrCard', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['HasCrCard', 'IsActiveMember'].
# checking for Gender and ('HasCrCard', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['HasCrCard', 'EstimatedSalary'].
# checking for Gender and ('HasCrCard', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['HasCrCard', 'CreditScore'].
# checking for Gender and ('IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['IsActiveMember', 'EstimatedSalary'].
# checking for Gender and ('IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['IsActiveMember', 'CreditScore'].
# checking for Gender and ('EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['EstimatedSalary', 'CreditScore'].

# %%
output = pd.DataFrame(result_list)
output.sort_values(by = 0, ascending = False)
# Out:
#                0          1                                  2
# 4   33499.477589  Geography              (Age, IsActiveMember)
# 2   28211.838285  Geography               (Age, NumOfProducts)
# 30  27347.699950     Gender               (Age, NumOfProducts)
# 1   25069.028532  Geography                     (Age, Balance)
# 47  23632.476321     Gender    (NumOfProducts, IsActiveMember)
# 19  23632.476321  Geography    (NumOfProducts, IsActiveMember)
# 6   20777.134027  Geography                 (Age, CreditScore)
# 34  20108.860066     Gender                 (Age, CreditScore)
# 41  19827.358373     Gender           (Balance, NumOfProducts)
# 13  19761.156169  Geography           (Balance, NumOfProducts)
# 5   19631.459458  Geography             (Age, EstimatedSalary)
# 28  19615.233406     Gender                      (Age, Tenure)
# 0   19434.446105  Geography                      (Age, Tenure)
# 3   19166.924040  Geography                   (Age, HasCrCard)
# 29  18880.028186     Gender                     (Age, Balance)
# 33  18774.063156     Gender             (Age, EstimatedSalary)
# 31  18262.629087     Gender                   (Age, HasCrCard)
# 32  17071.349328     Gender              (Age, IsActiveMember)
# 49  16235.412695     Gender       (NumOfProducts, CreditScore)
# 21  16230.508061  Geography       (NumOfProducts, CreditScore)
# 36  16108.836300     Gender            (Tenure, NumOfProducts)
# 8   16108.836300  Geography            (Tenure, NumOfProducts)
# 48  16101.822862     Gender   (NumOfProducts, EstimatedSalary)
# 46  16098.436652     Gender         (NumOfProducts, HasCrCard)
# 18  16098.436652  Geography         (NumOfProducts, HasCrCard)
# 20  16097.350039  Geography   (NumOfProducts, EstimatedSalary)
# 15  10313.877551  Geography          (Balance, IsActiveMember)
# 43  10311.985077     Gender          (Balance, IsActiveMember)
# 54   7516.094819     Gender      (IsActiveMember, CreditScore)
# 26   7507.894461  Geography      (IsActiveMember, CreditScore)
# 22   7425.291777  Geography        (HasCrCard, IsActiveMember)
# 50   7425.291777     Gender        (HasCrCard, IsActiveMember)
# 10   7410.593316  Geography           (Tenure, IsActiveMember)
# 38   7410.593316     Gender           (Tenure, IsActiveMember)
# 25   7347.760809  Geography  (IsActiveMember, EstimatedSalary)
# 53   7346.431309     Gender  (IsActiveMember, EstimatedSalary)
# 17   3090.364600  Geography             (Balance, CreditScore)
# 45   3068.355835     Gender             (Balance, CreditScore)
# 7    2965.560926  Geography                  (Tenure, Balance)
# 14   2945.870789  Geography               (Balance, HasCrCard)
# 16   2941.063017  Geography         (Balance, EstimatedSalary)
# 42   2933.264994     Gender               (Balance, HasCrCard)
# 44   2923.256538     Gender         (Balance, EstimatedSalary)
# 35   2915.311679     Gender                  (Tenure, Balance)
# 51   2050.353626     Gender       (HasCrCard, EstimatedSalary)
# 52   2027.730386     Gender           (HasCrCard, CreditScore)
# 37   1885.720861     Gender                (Tenure, HasCrCard)
# 40    307.943773     Gender              (Tenure, CreditScore)
# 12    287.994597  Geography              (Tenure, CreditScore)
# 55    286.648763     Gender     (EstimatedSalary, CreditScore)
# 24    283.114857  Geography           (HasCrCard, CreditScore)
# 27    261.301903  Geography     (EstimatedSalary, CreditScore)
# 39    215.508530     Gender          (Tenure, EstimatedSalary)
# 9     175.251051  Geography                (Tenure, HasCrCard)
# 11    165.344596  Geography          (Tenure, EstimatedSalary)
# 23    139.767006  Geography       (HasCrCard, EstimatedSalary)

# %%
#Get combinations
cat_list =['Geography', 'Gender'] 
num_list =['Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'CreditScore']

result_list_3 = []
three = list(combinations(num_list,3))
for i in cat_list:
    for j in three:
        print("checking for {} and {} combos.".format(i, j))
        kk = KMeansTransformer(cat_columns = [i], num_columns = [j[0],j[1], j[2]], n_clusters = 4)
        r = kk.fit(train)
        r1 = kk.transform(train)
        zz = pd.DataFrame(np.c_[r1, train.Exited])
        cc = pd.crosstab(zz.iloc[:,0], zz.iloc[:,1])
        result = st.chi2_contingency(cc)
        result_list_3.append((result.statistic, i, j))
        del r, r1, zz, cc, result
# Out:
# checking for Geography and ('Age', 'Tenure', 'Balance') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Tenure', 'Balance'].
# checking for Geography and ('Age', 'Tenure', 'NumOfProducts') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Tenure', 'NumOfProducts'].
# checking for Geography and ('Age', 'Tenure', 'HasCrCard') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Tenure', 'HasCrCard'].
# checking for Geography and ('Age', 'Tenure', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Tenure', 'IsActiveMember'].
# checking for Geography and ('Age', 'Tenure', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Tenure', 'EstimatedSalary'].
# checking for Geography and ('Age', 'Tenure', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Tenure', 'CreditScore'].
# checking for Geography and ('Age', 'Balance', 'NumOfProducts') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Balance', 'NumOfProducts'].
# checking for Geography and ('Age', 'Balance', 'HasCrCard') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Balance', 'HasCrCard'].
# checking for Geography and ('Age', 'Balance', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Balance', 'IsActiveMember'].
# checking for Geography and ('Age', 'Balance', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Balance', 'EstimatedSalary'].
# checking for Geography and ('Age', 'Balance', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'Balance', 'CreditScore'].
# checking for Geography and ('Age', 'NumOfProducts', 'HasCrCard') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'NumOfProducts', 'HasCrCard'].
# checking for Geography and ('Age', 'NumOfProducts', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'NumOfProducts', 'IsActiveMember'].
# checking for Geography and ('Age', 'NumOfProducts', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'NumOfProducts', 'EstimatedSalary'].
# checking for Geography and ('Age', 'NumOfProducts', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'NumOfProducts', 'CreditScore'].
# checking for Geography and ('Age', 'HasCrCard', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'HasCrCard', 'IsActiveMember'].
# checking for Geography and ('Age', 'HasCrCard', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'HasCrCard', 'EstimatedSalary'].
# checking for Geography and ('Age', 'HasCrCard', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'HasCrCard', 'CreditScore'].
# checking for Geography and ('Age', 'IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'IsActiveMember', 'EstimatedSalary'].
# checking for Geography and ('Age', 'IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'IsActiveMember', 'CreditScore'].
# checking for Geography and ('Age', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Age', 'EstimatedSalary', 'CreditScore'].
# checking for Geography and ('Tenure', 'Balance', 'NumOfProducts') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'Balance', 'NumOfProducts'].
# checking for Geography and ('Tenure', 'Balance', 'HasCrCard') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'Balance', 'HasCrCard'].
# checking for Geography and ('Tenure', 'Balance', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'Balance', 'IsActiveMember'].
# checking for Geography and ('Tenure', 'Balance', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'Balance', 'EstimatedSalary'].
# checking for Geography and ('Tenure', 'Balance', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'Balance', 'CreditScore'].
# checking for Geography and ('Tenure', 'NumOfProducts', 'HasCrCard') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'NumOfProducts', 'HasCrCard'].
# checking for Geography and ('Tenure', 'NumOfProducts', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'NumOfProducts', 'IsActiveMember'].
# checking for Geography and ('Tenure', 'NumOfProducts', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'NumOfProducts', 'EstimatedSalary'].
# checking for Geography and ('Tenure', 'NumOfProducts', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'NumOfProducts', 'CreditScore'].
# checking for Geography and ('Tenure', 'HasCrCard', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'HasCrCard', 'IsActiveMember'].
# checking for Geography and ('Tenure', 'HasCrCard', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'HasCrCard', 'EstimatedSalary'].
# checking for Geography and ('Tenure', 'HasCrCard', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'HasCrCard', 'CreditScore'].
# checking for Geography and ('Tenure', 'IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'IsActiveMember', 'EstimatedSalary'].
# checking for Geography and ('Tenure', 'IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'IsActiveMember', 'CreditScore'].
# checking for Geography and ('Tenure', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Tenure', 'EstimatedSalary', 'CreditScore'].
# checking for Geography and ('Balance', 'NumOfProducts', 'HasCrCard') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'NumOfProducts', 'HasCrCard'].
# checking for Geography and ('Balance', 'NumOfProducts', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'NumOfProducts', 'IsActiveMember'].
# checking for Geography and ('Balance', 'NumOfProducts', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'NumOfProducts', 'EstimatedSalary'].
# checking for Geography and ('Balance', 'NumOfProducts', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'NumOfProducts', 'CreditScore'].
# checking for Geography and ('Balance', 'HasCrCard', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'HasCrCard', 'IsActiveMember'].
# checking for Geography and ('Balance', 'HasCrCard', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'HasCrCard', 'EstimatedSalary'].
# checking for Geography and ('Balance', 'HasCrCard', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'HasCrCard', 'CreditScore'].
# checking for Geography and ('Balance', 'IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'IsActiveMember', 'EstimatedSalary'].
# checking for Geography and ('Balance', 'IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'IsActiveMember', 'CreditScore'].
# checking for Geography and ('Balance', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['Balance', 'EstimatedSalary', 'CreditScore'].
# checking for Geography and ('NumOfProducts', 'HasCrCard', 'IsActiveMember') combos.
# Creating transformer combos for ['Geography'] and ['NumOfProducts', 'HasCrCard', 'IsActiveMember'].
# checking for Geography and ('NumOfProducts', 'HasCrCard', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['NumOfProducts', 'HasCrCard', 'EstimatedSalary'].
# checking for Geography and ('NumOfProducts', 'HasCrCard', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['NumOfProducts', 'HasCrCard', 'CreditScore'].
# checking for Geography and ('NumOfProducts', 'IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['NumOfProducts', 'IsActiveMember', 'EstimatedSalary'].
# checking for Geography and ('NumOfProducts', 'IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['NumOfProducts', 'IsActiveMember', 'CreditScore'].
# checking for Geography and ('NumOfProducts', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['NumOfProducts', 'EstimatedSalary', 'CreditScore'].
# checking for Geography and ('HasCrCard', 'IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Geography'] and ['HasCrCard', 'IsActiveMember', 'EstimatedSalary'].
# checking for Geography and ('HasCrCard', 'IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['HasCrCard', 'IsActiveMember', 'CreditScore'].
# checking for Geography and ('HasCrCard', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['HasCrCard', 'EstimatedSalary', 'CreditScore'].
# checking for Geography and ('IsActiveMember', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Geography'] and ['IsActiveMember', 'EstimatedSalary', 'CreditScore'].
# checking for Gender and ('Age', 'Tenure', 'Balance') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Tenure', 'Balance'].
# checking for Gender and ('Age', 'Tenure', 'NumOfProducts') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Tenure', 'NumOfProducts'].
# checking for Gender and ('Age', 'Tenure', 'HasCrCard') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Tenure', 'HasCrCard'].
# checking for Gender and ('Age', 'Tenure', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Tenure', 'IsActiveMember'].
# checking for Gender and ('Age', 'Tenure', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Tenure', 'EstimatedSalary'].
# checking for Gender and ('Age', 'Tenure', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Tenure', 'CreditScore'].
# checking for Gender and ('Age', 'Balance', 'NumOfProducts') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Balance', 'NumOfProducts'].
# checking for Gender and ('Age', 'Balance', 'HasCrCard') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Balance', 'HasCrCard'].
# checking for Gender and ('Age', 'Balance', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Balance', 'IsActiveMember'].
# checking for Gender and ('Age', 'Balance', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Balance', 'EstimatedSalary'].
# checking for Gender and ('Age', 'Balance', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'Balance', 'CreditScore'].
# checking for Gender and ('Age', 'NumOfProducts', 'HasCrCard') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'NumOfProducts', 'HasCrCard'].
# checking for Gender and ('Age', 'NumOfProducts', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'NumOfProducts', 'IsActiveMember'].
# checking for Gender and ('Age', 'NumOfProducts', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'NumOfProducts', 'EstimatedSalary'].
# checking for Gender and ('Age', 'NumOfProducts', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'NumOfProducts', 'CreditScore'].
# checking for Gender and ('Age', 'HasCrCard', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'HasCrCard', 'IsActiveMember'].
# checking for Gender and ('Age', 'HasCrCard', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'HasCrCard', 'EstimatedSalary'].
# checking for Gender and ('Age', 'HasCrCard', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'HasCrCard', 'CreditScore'].
# checking for Gender and ('Age', 'IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'IsActiveMember', 'EstimatedSalary'].
# checking for Gender and ('Age', 'IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'IsActiveMember', 'CreditScore'].
# checking for Gender and ('Age', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Age', 'EstimatedSalary', 'CreditScore'].
# checking for Gender and ('Tenure', 'Balance', 'NumOfProducts') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'Balance', 'NumOfProducts'].
# checking for Gender and ('Tenure', 'Balance', 'HasCrCard') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'Balance', 'HasCrCard'].
# checking for Gender and ('Tenure', 'Balance', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'Balance', 'IsActiveMember'].
# checking for Gender and ('Tenure', 'Balance', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'Balance', 'EstimatedSalary'].
# checking for Gender and ('Tenure', 'Balance', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'Balance', 'CreditScore'].
# checking for Gender and ('Tenure', 'NumOfProducts', 'HasCrCard') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'NumOfProducts', 'HasCrCard'].
# checking for Gender and ('Tenure', 'NumOfProducts', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'NumOfProducts', 'IsActiveMember'].
# checking for Gender and ('Tenure', 'NumOfProducts', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'NumOfProducts', 'EstimatedSalary'].
# checking for Gender and ('Tenure', 'NumOfProducts', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'NumOfProducts', 'CreditScore'].
# checking for Gender and ('Tenure', 'HasCrCard', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'HasCrCard', 'IsActiveMember'].
# checking for Gender and ('Tenure', 'HasCrCard', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'HasCrCard', 'EstimatedSalary'].
# checking for Gender and ('Tenure', 'HasCrCard', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'HasCrCard', 'CreditScore'].
# checking for Gender and ('Tenure', 'IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'IsActiveMember', 'EstimatedSalary'].
# checking for Gender and ('Tenure', 'IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'IsActiveMember', 'CreditScore'].
# checking for Gender and ('Tenure', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Tenure', 'EstimatedSalary', 'CreditScore'].
# checking for Gender and ('Balance', 'NumOfProducts', 'HasCrCard') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'NumOfProducts', 'HasCrCard'].
# checking for Gender and ('Balance', 'NumOfProducts', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'NumOfProducts', 'IsActiveMember'].
# checking for Gender and ('Balance', 'NumOfProducts', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'NumOfProducts', 'EstimatedSalary'].
# checking for Gender and ('Balance', 'NumOfProducts', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'NumOfProducts', 'CreditScore'].
# checking for Gender and ('Balance', 'HasCrCard', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'HasCrCard', 'IsActiveMember'].
# checking for Gender and ('Balance', 'HasCrCard', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'HasCrCard', 'EstimatedSalary'].
# checking for Gender and ('Balance', 'HasCrCard', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'HasCrCard', 'CreditScore'].
# checking for Gender and ('Balance', 'IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'IsActiveMember', 'EstimatedSalary'].
# checking for Gender and ('Balance', 'IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'IsActiveMember', 'CreditScore'].
# checking for Gender and ('Balance', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['Balance', 'EstimatedSalary', 'CreditScore'].
# checking for Gender and ('NumOfProducts', 'HasCrCard', 'IsActiveMember') combos.
# Creating transformer combos for ['Gender'] and ['NumOfProducts', 'HasCrCard', 'IsActiveMember'].
# checking for Gender and ('NumOfProducts', 'HasCrCard', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['NumOfProducts', 'HasCrCard', 'EstimatedSalary'].
# checking for Gender and ('NumOfProducts', 'HasCrCard', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['NumOfProducts', 'HasCrCard', 'CreditScore'].
# checking for Gender and ('NumOfProducts', 'IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['NumOfProducts', 'IsActiveMember', 'EstimatedSalary'].
# checking for Gender and ('NumOfProducts', 'IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['NumOfProducts', 'IsActiveMember', 'CreditScore'].
# checking for Gender and ('NumOfProducts', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['NumOfProducts', 'EstimatedSalary', 'CreditScore'].
# checking for Gender and ('HasCrCard', 'IsActiveMember', 'EstimatedSalary') combos.
# Creating transformer combos for ['Gender'] and ['HasCrCard', 'IsActiveMember', 'EstimatedSalary'].
# checking for Gender and ('HasCrCard', 'IsActiveMember', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['HasCrCard', 'IsActiveMember', 'CreditScore'].
# checking for Gender and ('HasCrCard', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['HasCrCard', 'EstimatedSalary', 'CreditScore'].
# checking for Gender and ('IsActiveMember', 'EstimatedSalary', 'CreditScore') combos.
# Creating transformer combos for ['Gender'] and ['IsActiveMember', 'EstimatedSalary', 'CreditScore'].

# %%
output3 = pd.DataFrame(result_list_3)
output3.sort_values(by = 0, ascending = False)
# Out:
#                0          1                                          2
# 14  27553.887934  Geography          (Age, NumOfProducts, CreditScore)
# 70  27520.413111     Gender          (Age, NumOfProducts, CreditScore)
# 1   27432.045800  Geography               (Age, Tenure, NumOfProducts)
# 69  26100.689370     Gender      (Age, NumOfProducts, EstimatedSalary)
# 13  26069.583601  Geography      (Age, NumOfProducts, EstimatedSalary)
# ..           ...        ...                                        ...
# 54    164.694091  Geography  (HasCrCard, EstimatedSalary, CreditScore)
# 31    156.161866  Geography       (Tenure, HasCrCard, EstimatedSalary)
# 87    153.073705     Gender       (Tenure, HasCrCard, EstimatedSalary)
# 91    141.307135     Gender     (Tenure, EstimatedSalary, CreditScore)
# 35    133.767848  Geography     (Tenure, EstimatedSalary, CreditScore)
#
# [112 rows x 3 columns]
